# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\Admin\Documents\Documents\coding projects\algorithms-and-data-structures\ml\height-weight.csv', sep=';')
df.columns = df.columns.str.strip().str.replace(r'\s+', '', regex=True)

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
print(df.columns.tolist())
print(df.columns)
# Out:
# ['Weight', 'Height']
# Index(['Weight', 'Height'], dtype='str')

# %%
X = df['Weight'].values
Y = df['Height'].values

# %%
# Mean
mean_x = np.mean(X)
mean_y = np.mean(Y)

# Calculate slope (m) and intercept (b)
numerator = np.sum((X - mean_x) * (Y - mean_y))
denominator = np.sum((X - mean_x) ** 2)

m = numerator / denominator
b = mean_y - m * mean_x

print("Slope:", m)
print("Intercept:", b)
# Out:
# Slope: 0.968242909156291
# Intercept: 90.4417674293163

# %%
Y_pred = m * X + b

plt.scatter(X, Y)
plt.plot(X, Y_pred)
plt.xlabel('Weight')
plt.ylabel('Height')
plt.title('Linear Regression Fit')
plt.show()

# %%
weight = 65
predicted_height = m * weight + b

print("Predicted height:", predicted_height)
# Out:
# Predicted height: 153.3775565244752
